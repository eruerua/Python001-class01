# %%
import pandas as pd

# %%
df = pd.read_csv('phones.csv',header = None)

# %%
df.head()
# Out:
#                                                    0  \
# 0  \n                                MI 小米 10 5G智...
# 1  \n                                MI 小米 10 5G智...
# 2  \n                                MI 小米 10 5G智...
# 3  \n                                MI 小米 10 5G智...
# 4  \n                                MI 小米 10 5G智...
#
#                                                    1
# 0                            不打游戏，中度使用，可以从早上9点到晚上9点
# 1                                        我一开始就是3700
# 2                                     只有我打开不是这个价格吗？
# 3  拍照确实这样，边上默认虚化了，也没法关，用了小半年，现在经常会卡，每天需要一键优化好几次，还...
# 4  我是618买的，到手是华星屏，边角一圈发红，前置摄像头是歪的，联系客服换货换了个不发绿的三星...

# %%
df[0].strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-b212e4fcd69d> in <module>()
# ----> 1 df[0].strip()
#
# D:\Anaconda3\envs\tfgpu\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
df.loc[0,0].strip()
# Out:
# 'MI 小米 10 5G智能手机 8GB+256GB'

# %%
df.loc[20,1].strip()
# Out:
# ''

# %%
df[df[1]=="  "]
# Out:
#                                                      0   1
# 20   \n                百亿补贴：                       ...
# 27   \n                百亿补贴：                       ...
# 35   \n                百亿补贴：                       ...
# 37   \n                百亿补贴：                       ...
# 44   \n                                MI 小米10 至尊纪念...
# 46   \n                                MI 小米10 至尊纪念...
# 52   \n                                MI 小米10 至尊纪念...
# 55   \n                                MI 小米10 至尊纪念...
# 61   \n                                MI 小米10 至尊纪念...
# 72   \n                                MI 小米10 至尊纪念...
# 73   \n                                MI 小米10 至尊纪念...
# 76   \n                                MI 小米10 至尊纪念...
# 96   \n                                MI 小米10 至尊纪念...
# 100  \n                                MI 小米10 至尊纪念...
# 104  \n                                MI 小米10 至尊纪念...
# 108  \n                                MI 小米10 至尊纪念...
# ...

# %%
s='22点开始、京东PLUS会员：                                Redmi 红米 K30 5G版 智能手机 8GB+128GB 全网通 花影惊鸿'

# %%
' '.join(s.split())
# Out:
# '22点开始、京东PLUS会员： Redmi 红米 K30 5G版 智能手机 8GB+128GB 全网通 花影惊鸿'
